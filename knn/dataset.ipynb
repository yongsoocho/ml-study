# %%
import kaggle

# 데이터셋 경로, 경진대회 명칭 (URL의 뒷부분: 'user/dataset-name')
dataset = 'vipullrathod/fish-market' 

# 다운로드 및 압축 해제
kaggle.api.dataset_download_files(dataset, path='./data', unzip=True)

print("데이터 다운로드 완료!")
# Out:
# Dataset URL: https://www.kaggle.com/datasets/vipullrathod/fish-market
# 데이터 다운로드 완료!
